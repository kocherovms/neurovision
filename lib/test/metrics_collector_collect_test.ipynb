# %%
project_root_dir = !git rev-parse --show-toplevel
project_root_dir = project_root_dir[0]

import os
import sys

sys.path.append(os.path.join(project_root_dir, 'lib'))
from metrics_collector import *

# %%
collector = RmqSummaryCollector('/home/misha/tmp/tensorboard_test', 'amqp://guest:guest@localhost:5672/%2F')
collector.run()
# Out:
# 2026-05-04 09:03:45.515909: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-04 09:03:45.749819: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-05-04 09:03:47.002975: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Creating SummaryWriter for log_dir=/home/misha/tmp/tensorboard_test/test_model_42/99 (base_log_dir=/home/misha/tmp/tensorboard_test)
# add_scalar, log_dir='test_model_42/99', tag='loss', scalar_value=0.02, global_step=100
# add_text, log_dir='test_model_42/99', tag='meta', text_string[:1000]='hello_world!', global_step=100
# add_figure, log_dir='test_model_42/99', tag='figure', image_data.shape=(3, 480, 640), global_step=100
# add_hparams, log_dir='test_model_42/99', hparam_dict={'C': 1.0, 'kernel': 'rbf'}, metric_dict={'accuracy': 0.95, 'f1_score': 0.93}, run_name='svc-443'
# flush
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# add_video_file, log_dir='test_model_42/99', tag='video', video_tensor.shape=torch.Size([1, 7013, 3, 210, 160]) (torch.uint8) (346834 bytes), global_step=1, fps=30.0
# flush
# add_file, log_dir='test_model_42/99', file_name='test_video.mp4' (346834 bytes)
# add_file, log_dir='test_model_42/99', file_name='test_video2.mp4' (346834 bytes)
# add_text, log_dir='test_model_42/99', tag='videos', text_string[:1000]='<a href="http://localhost:6007/test_model_42/99/test_video.mp4" target="_blank">test_video.mp4</a><br><a href="http://localhost:6007/test_model_42/99/test_video2.mp4" target="_blank">test_video2.mp4</a>', global_step=0
# flush
# flush
# flush
# add_scalar (on flush), log_dir='test_model_42/99', tag='metric1', scalar_value=1, global_step=1
# add_scalar (on flush), log_dir='test_model_42/99', tag='metric2', scalar_value=2, global_step=1
# add_scalar (on flush), log_dir='test_model_42/99', tag='metric3', scalar_value=3, global_step=1
# flush
# add_scalar (on flush), log_dir='test_model_42/99', tag='metric1', scalar_value=1, global_step=1
# add_scalar (on flush), log_dir='test_model_42/99', tag='metric2', scalar_value=2, global_step=1
# add_scalar (on flush), log_dir='test_model_42/99', tag='metric3', scalar_value=3, global_step=1
# add_scalar (on flush), log_dir='test_model_42/99', tag='metric4', scalar_value=4, global_step=1
# flush
# add_scalar (on flush), log_dir='test_model_42/99', tag='metric1', scalar_value=1, global_step=1
# add_scalar (on flush), log_dir='test_model_42/99', tag='metric2', scalar_value=2, global_step=1
# add_scalar (on flush), log_dir='test_model_42/99', tag='metric3', scalar_value=3, global_step=1
# flush
# add_scalar (on flush), log_dir='test_model_42/99', tag='metric4', scalar_value=4, global_step=1
# flush
# add_scalar (on flush), log_dir='test_model_42/99', tag='metric4', scalar_value=4, global_step=1
# flush
# add_scalar (on flush), log_dir='test_model_42/99', tag='metric1', scalar_value=1, global_step=1
# add_scalar (on flush), log_dir='test_model_42/99', tag='metric2', scalar_value=2, global_step=1
# add_scalar (on flush), log_dir='test_model_42/99', tag='metric3', scalar_value=3, global_step=1
# flush
# add_scalar, log_dir='test_model_42/99', tag='loss', scalar_value=0.02, global_step=100
# add_text, log_dir='test_model_42/99', tag='meta', text_string[:1000]='hello_world!', global_step=100
# add_figure, log_dir='test_model_42/99', tag='figure', image_data.shape=(3, 480, 640), global_step=100
# add_hparams, log_dir='test_model_42/99', hparam_dict={'C': 1.0, 'kernel': 'rbf'}, metric_dict={'accuracy': 0.95, 'f1_score': 0.93}, run_name='svc-443'
# flush
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 collector = RmqSummaryCollector('/home/misha/tmp/tensorboard_test', 'amqp://guest:guest@localhost:5672/%2F')
# ----> 2 collector.run()
#
# File ~/dev/mine/neurolab/lib/metrics_collector.py:191, in run(self)
#     188 def run(self):
#     189     self.channel.basic_qos(prefetch_count=1) # max 1 unacked message, i.e. serial processing
#     190     self.channel.basic_consume(
# --> 191         queue=RMQ_EVENTS_QUEUE_NAME,
#     192         on_message_callback=self.on_message,
#     193         auto_ack=False)
#     194     self.channel.start_consuming()
#
# File ~/anaconda3/envs/mine/lib/python3.12/site-packages/pika/adapters/blocking_connection.py:1883, in BlockingChannel.start_consuming(self)
#    1880 # Process events as long as consumers exist on this channel
#    1881 while self._consumer_infos:
#    1882     # This will raise ChannelClosed if channel is closed by broker
# -> 1883     self._process_data_events(time_limit=None)
#
# File ~/anaconda3/envs/mine/lib/python3.12/site-packages/pika/adapters/blocking_connection.py:2044, in BlockingChannel._process_data_events(self, time_limit)
#    2025 def _process_data_events(self, time_limit):
#    2026     """Wrapper for `BlockingConnection.process_data_events()` with common
#    2027     channel-specific logic that raises ChannelClosed if broker closed this
#    2028     channel.
#    (...)
#    2042
#    2043     """
# -> 2044     self.connection.process_data_events(time_limit=time_limit)
#    2045     if self.is_closed and isinstance(self._closing_reason,
#    2046                                      exceptions.ChannelClosedByBroker):
#    2047         LOGGER.debug('Channel close by broker detected, raising %r; %r',
#    2048                      self._closing_reason, self)
#
# File ~/anaconda3/envs/mine/lib/python3.12/site-packages/pika/adapters/blocking_connection.py:842, in BlockingConnection.process_data_events(self, time_limit)
#     838 common_terminator = lambda: bool(dispatch_acquired and
#     839                                  (self._channels_pending_dispatch or
#     840                                   self._ready_events))
#     841 if time_limit is None:
# --> 842     self._flush_output(common_terminator)
#     843 else:
#     844     with _IoloopTimerContext(time_limit, self._impl) as timer:
#
# File ~/anaconda3/envs/mine/lib/python3.12/site-packages/pika/adapters/blocking_connection.py:514, in BlockingConnection._flush_output(self, *waiters)
#     512 # Process I/O until our completion condition is satisfied
#     513 while not is_done():
# --> 514     self._impl.ioloop.poll()
#     515     self._impl.ioloop.process_timeouts()
#     517 if self._closed_result.ready:
#
# File ~/anaconda3/envs/mine/lib/python3.12/site-packages/pika/adapters/select_connection.py:579, in IOLoop.poll(self)
#     572 def poll(self):
#     573     """[Extension] Wait for events of interest on registered file
#     574     descriptors until an event of interest occurs or next timer deadline or
#     575     `_PollerBase._MAX_POLL_TIMEOUT`, whichever is sooner, and dispatch the
#     576     corresponding event handlers.
#     577
#     578     """
# --> 579     self._poller.poll()
#
# File ~/anaconda3/envs/mine/lib/python3.12/site-packages/pika/adapters/select_connection.py:1184, in PollPoller.poll(self)
#    1182 while True:
#    1183     try:
# -> 1184         events = self._poll.poll(self._get_max_wait())
#    1185         break
#    1186     except _SELECT_ERRORS as error:
#
# KeyboardInterrupt:
